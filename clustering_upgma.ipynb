# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = {
 ('A', 'A'): np.nan,

 ('B', 'A'): 19,
 ('C', 'A'): 27,
 ('D', 'A'): 8,
 ('E', 'A'): 33,
 ('F', 'A'): 18,
 ('G', 'A'): 13,

 ('C', 'B'): 31,
 ('D', 'B'): 18,
 ('E', 'B'): 36,
 ('F', 'B'): 1,
 ('G', 'B'): 13,

 ('D', 'C'): 26,
 ('E', 'C'): 41,
 ('F', 'C'): 32,
 ('G', 'C'): 29,

 ('E', 'D'): 31,
 ('F', 'D'): 17,
 ('G', 'D'): 14,

 ('F', 'E'): 35,
 ('G', 'E'): 28,

 ('G', 'F'): 12,

 ('G', 'G'): np.nan
 }
data = pd.Series(data).unstack()
data = data.fillna(0) + data.T.fillna(0)
data
# Out:
#       A     B     C     D     E     F     G
# A   0.0  19.0  27.0   8.0  33.0  18.0  13.0
# B  19.0   0.0  31.0  18.0  36.0   1.0  13.0
# C  27.0  31.0   0.0  26.0  41.0  32.0  29.0
# D   8.0  18.0  26.0   0.0  31.0  17.0  14.0
# E  33.0  36.0  41.0  31.0   0.0  35.0  28.0
# F  18.0   1.0  32.0  17.0  35.0   0.0  12.0
# G  13.0  13.0  29.0  14.0  28.0  12.0   0.0

# %%
sns.clustermap(data)
# Out:
# /homes/sjanssen/miniconda3/envs/notebookServer/lib/python3.10/site-packages/seaborn/matrix.py:530: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(self.array, method=self.method,
